# %%
import random 
import math

random.seed(123456)

R = 6371000.0
def distance(p1,p2):
    return math.sqrt((p1[0] - p2[0])**2 + (math.cos(p1[0])*(p1[1] - p2[1]))**2) * R
    
def get_mean(points):
    np = len(points)
    sump = [0,0]
    if np == 0:
        return sump
    for p in points:
        sump[0] += p[0]
        sump[1] += p[1]
    sump[0] = sump[0]/np
    sump[1] = sump[1]/np
    return sump

def associate(centers, points, associated):
    nchanged = 0
    for ip, p in enumerate(points):
        closest = None
        mindist = 1e10
        for ic, c in enumerate(centers):
            dist = distance(p, c)
            if dist < mindist:
                mindist = dist
                closest = ic
        if closest is None: print("Something wrong. Look into associate function!")
        if associated[ip] != closest:
            associated[ip] = closest
            nchanged += 1
    return float(nchanged)/len(points)

def get_centroids(points, associated, kcls):
    center_points = [[] for _ in range(kcls)]
    for ip, p in enumerate(points):
        center_points[associated[ip]].append(p)
    centroids = []
    for icls in range(kcls):
        mean = get_mean(center_points[icls])
        centroids.append(mean)
    return centroids

def kmeans(points, kcls, max_iter=1000, min_shift_frac=0.01):
    
    npoints = len(points)
    if npoints <= kcls**2: kcls = int(npoints**0.5)
    
    centers = random.sample(points, kcls)
    associated = [0 for _ in points]
    for iter in range(max_iter):
        changed_fraction = associate(centers, points, associated)
        if changed_fraction <= min_shift_frac:
            print("changed_fraction({}) reached to min_shift_frac({})".format(changed_fraction, min_shift_frac))
            break
        if iter == max_iter-1:
            print("max_iter({}) reached.".format(iter))
    return associated

# %%
data = []
for iline, line in enumerate(open('crash2.csv', 'r')):
    if iline == 0: continue
    p = line.strip().split(",")
    data.append((float(p[0]),float(p[1])))

kcls = 4
associated = kmeans(data, kcls, max_iter=500, min_shift_frac=0.01)
centroids = get_centroids(data, associated, kcls)
# Out:
# changed_fraction(0.0) reached to min_shift_frac(0.01)

# %%
centroids
# Out:
# [[41.893113077099976, -87.6512527903],
#  [41.89503547777777, -87.65385070714285],
#  [41.89152598206895, -87.64898402718391],
#  [41.893799806636636, -87.65704604555538]]

# %%
associated
# Out:
# [3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  0,
#  1,
#  1,
#  3,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  0,
#  3,
#  3,
#  0,
#  3,
#  2,
#  1,
#  2,
#  3,
#  1,
#  2,
#  0,
#  2,
#  1,
#  2,
#  3,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  3,
#  1,
#  3,
#  1,
#  0,
#  0,
#  3,
#  2,
#  2,
#  1,
#  3,
#  3,
#  3,
#  0,
#  3,
#  0,
#  3,
#  3,
#  3,
#  0,
#  2,
#  0,
#  3,
#  3,
#  1,
#  0,
#  2,
#  3,
#  1,
#  1,
#  3,
#  3,
#  0,
#  3,
#  3,
#  2,
#  3,
#  0,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  0,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  0,
#  3,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  2,
#  0,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  0,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  2,
#  0,
#  0,
#  2,
#  3,
#  2,
#  1,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  0,
#  3,
#  0,
#  0,
#  2,
#  2,
#  0,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  0,
#  2,
#  2,
#  3,
#  3,
#  3,
#  0,
#  3,
#  2,
#  3,
#  1,
#  0,
#  0,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  2,
#  2,
#  1,
#  2,
#  0,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  0,
#  2,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  0,
#  3,
#  2,
#  0,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  0,
#  1,
#  3,
#  0,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2,
#  1,
#  0,
#  3,
#  0,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  0,
#  1,
#  3,
#  2,
#  2,
#  1,
#  3,
#  3,
#  3,
#  0,
#  2,
#  3,
#  2,
#  3,
#  2,
#  2,
#  0,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  2,
#  3,
#  1,
#  3,
#  2,
#  2,
#  3,
#  0,
#  0,
#  3,
#  1,
#  3,
#  0,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  0,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  3,
#  0,
#  3,
#  3,
#  3,
#  0,
#  2,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  0,
#  2,
#  3,
#  0,
#  2,
#  2,
#  2,
#  0,
#  2,
#  1,
#  3,
#  0,
#  2,
#  2,
#  2,
#  0,
#  2,
#  0,
#  3,
#  3,
#  3,
#  0,
#  2,
#  2,
#  3,
#  0,
#  2,
#  3,
#  0,
#  0,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  2,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  1,
#  0,
#  1,
#  0,
#  3,
#  2,
#  2,
#  3,
#  2,
#  1,
#  0,
#  2,
#  2,
#  1,
#  0,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  0,
#  3,
#  3,
#  0,
#  2,
#  3,
#  2,
#  0,
#  2,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  0,
#  2,
#  3,
#  3,
#  0,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  0,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  1,
#  0,
#  3,
#  2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  3,
#  0,
#  0,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  0,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  1,
#  0,
#  0,
#  2,
#  1,
#  3,
#  2,
#  0,
#  0,
#  2,
#  2,
#  3,
#  2,
#  2,
#  1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  0,
#  2,
#  0,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  0,
#  0,
#  2,
#  3,
#  3,
#  0,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  0,
#  3,
#  0,
#  0,
#  3,
#  0,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  0,
#  1,
#  2,
#  2,
#  3,
#  3,
#  3,
#  0,
#  2,
#  1,
#  3,
#  2,
#  3,
#  2,
#  0,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  0,
#  0,
#  3,
#  3,
#  1,
#  1,
#  3,
#  0,
#  3,
#  1,
#  3,
#  3,
#  3,
#  0,
#  0,
#  2,
#  3,
#  2,
#  0,
#  3,
#  3,
#  0]

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
average_max = -1
kcls_max = None

for i in range(3,50):
    kcls = i
    associated = kmeans(data, kcls, max_iter=500, min_shift_frac=0.01)
    centroids = get_centroids(data, associated, kcls)
    silhouette_avg = silhouette_score(data,associated)
    print("For kcls =", kcls,
          "The average silhouette_score is :", silhouette_avg)
    
    print(silhouette_avg)
    if silhouette_avg > average_max:
        average_max = silhouette_avg
        kcls_max = kcls
print(kcls_max, average_max)
# Out:
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 3 The average silhouette_score is : 0.4531823797590823
# 0.4531823797590823
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 4 The average silhouette_score is : 0.4970403684136513
# 0.4970403684136513
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 5 The average silhouette_score is : 0.3392964407003656
# 0.3392964407003656
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 6 The average silhouette_score is : 0.4452379710857146
# 0.4452379710857146
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 7 The average silhouette_score is : 0.33410534266746766
# 0.33410534266746766
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 8 The average silhouette_score is : 0.27163210556763034
# 0.27163210556763034
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 9 The average silhouette_score is : 0.3496212118759795
# 0.3496212118759795
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 10 The average silhouette_score is : 0.3779278791374973
# 0.3779278791374973
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 11 The average silhouette_score is : 0.2729650906273492
# 0.2729650906273492
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 12 The average silhouette_score is : 0.27352349819585986
# 0.27352349819585986
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 13 The average silhouette_score is : 0.3996749684777681
# 0.3996749684777681
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 14 The average silhouette_score is : 0.32424082654736663
# 0.32424082654736663
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 15 The average silhouette_score is : 0.347706430221606
# 0.347706430221606
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 16 The average silhouette_score is : 0.3612453212297154
# 0.3612453212297154
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 17 The average silhouette_score is : 0.3482797201363783
# 0.3482797201363783
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 18 The average silhouette_score is : 0.0998412471121161
# 0.0998412471121161
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 19 The average silhouette_score is : 0.3489768268106961
# 0.3489768268106961
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 20 The average silhouette_score is : 0.3352013356968962
# 0.3352013356968962
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 21 The average silhouette_score is : 0.14197526254202564
# 0.14197526254202564
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 22 The average silhouette_score is : 0.37983707990487586
# 0.37983707990487586
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 23 The average silhouette_score is : 0.30286256967186953
# 0.30286256967186953
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 24 The average silhouette_score is : 0.43371831961238877
# 0.43371831961238877
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 25 The average silhouette_score is : 0.42182199988221764
# 0.42182199988221764
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 26 The average silhouette_score is : 0.3535722594958788
# 0.3535722594958788
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 27 The average silhouette_score is : 0.2997472480967114
# 0.2997472480967114
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 28 The average silhouette_score is : 0.2631353510643045
# 0.2631353510643045
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 29 The average silhouette_score is : 0.3861855546650579
# 0.3861855546650579
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 30 The average silhouette_score is : 0.3710795336624984
# 0.3710795336624984
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 31 The average silhouette_score is : 0.29662002907989043
# 0.29662002907989043
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 32 The average silhouette_score is : 0.24903786701071193
# 0.24903786701071193
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 33 The average silhouette_score is : 0.3472129266748577
# 0.3472129266748577
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 34 The average silhouette_score is : 0.3119184356505872
# 0.3119184356505872
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 35 The average silhouette_score is : 0.38166599492474007
# 0.38166599492474007
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 36 The average silhouette_score is : 0.3675519364863665
# 0.3675519364863665
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 37 The average silhouette_score is : 0.3633765120330725
# 0.3633765120330725
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 38 The average silhouette_score is : 0.3121984825030858
# 0.3121984825030858
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 39 The average silhouette_score is : 0.39095077562795494
# 0.39095077562795494
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 40 The average silhouette_score is : 0.23331012134807372
# 0.23331012134807372
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 41 The average silhouette_score is : 0.31125898900499743
# 0.31125898900499743
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 42 The average silhouette_score is : 0.15234346704373955
# 0.15234346704373955
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 43 The average silhouette_score is : 0.2770861108622865
# 0.2770861108622865
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 44 The average silhouette_score is : 0.30241454317389943
# 0.30241454317389943
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 45 The average silhouette_score is : 0.22324959411859696
# 0.22324959411859696
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 46 The average silhouette_score is : 0.24057390978509813
# 0.24057390978509813
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 47 The average silhouette_score is : 0.3861255196051982
# 0.3861255196051982
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 48 The average silhouette_score is : 0.32357236702348796
# 0.32357236702348796
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# For kcls = 49 The average silhouette_score is : 0.2638249081067937
# 0.2638249081067937
# 4 0.4970403684136513

# %%
first_part = """
<!DOCTYPE html>
<html>
<head>
<meta name="viewport" content="initial-scale=1.0, width=device-width" />
<link rel="stylesheet" type="text/css" href="https://js.api.here.com/v3/3.0/mapsjs-ui.css?dp-version=1542186754" />
<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-core.js"></script>
<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-service.js"></script>
<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-ui.js"></script>
<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-mapevents.js"></script>

</head>
<body>
  <div id="map" style="width: 100%; height: 800px; background: grey" />
  <script  type="text/javascript" charset="UTF-8" >
    

/**
 * Adds markers to the map highlighting the locations of the captials of
 * France, Italy, Germany, Spain and the United Kingdom.
 *
 * @param  {H.Map} map      A HERE Map instance within the application
 */
function addMarkersToMap(map) {
  //var parisMarker = new H.map.Marker({lat:48.8567, lng:2.3508});
  //map.addObject(parisMarker);
}

/**
 * Boilerplate map initialization code starts below:
 */

//Step 1: initialize communication with the platform
var platform = new H.service.Platform({
  app_id: 'devportal-demo-20180625',
  app_code: '9v2BkviRwi9Ot26kp2IysQ',
  useHTTPS: true
});
var pixelRatio = window.devicePixelRatio || 1;
var defaultLayers = platform.createDefaultLayers({
  tileSize: pixelRatio === 1 ? 256 : 512,
  ppi: pixelRatio === 1 ? undefined : 320
});

//Step 2: initialize a map - this map is centered over Europe
var map = new H.Map(document.getElementById('map'),
  defaultLayers.normal.map,{
  center: {lat:41, lng:-87},
  zoom: 4,
  pixelRatio: pixelRatio
});

//Step 3: make the map interactive
// MapEvents enables the event system
// Behavior implements default interactions for pan/zoom (also on mobile touch environments)
var behavior = new H.mapevents.Behavior(new H.mapevents.MapEvents(map));

// Create the default UI components
var ui = H.ui.UI.createDefault(map, defaultLayers);

"""

last_part = """

// Now use the map as required...
addMarkersToMap(map);
  </script>
</body>
</html>
"""

# %%
first_part
# Out:
# '\n<!DOCTYPE html>\n<html>\n<head>\n<meta name="viewport" content="initial-scale=1.0, width=device-width" />\n<link rel="stylesheet" type="text/css" href="https://js.api.here.com/v3/3.0/mapsjs-ui.css?dp-version=1542186754" />\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-core.js"></script>\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-service.js"></script>\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-ui.js"></script>\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-mapevents.js"></script>\n\n</head>\n<body>\n  <div id="map" style="width: 100%; height: 800px; background: grey" />\n  <script  type="text/javascript" charset="UTF-8" >\n    \n\n/**\n * Adds markers to the map highlighting the locations of the captials of\n * France, Italy, Germany, Spain and the United Kingdom.\n *\n * @param  {H.Map} map      A HERE Map instance within the application\n */\nfunction addMarkersToMap(map) {\n  //var parisMarker = new H.map.Marker({lat:48.8567, lng:2.3508});\n  //map.addObject(parisMarker);\n}\n\n/**\n * Boilerplate map initialization code starts below:\n */\n\n//Step 1: initialize communication with the platform\nvar platform = new H.service.Platform({\n  app_id: \'devportal-demo-20180625\',\n  app_code: \'9v2BkviRwi9Ot26kp2IysQ\',\n  useHTTPS: true\n});\nvar pixelRatio = window.devicePixelRatio || 1;\nvar defaultLayers = platform.createDefaultLayers({\n  tileSize: pixelRatio === 1 ? 256 : 512,\n  ppi: pixelRatio === 1 ? undefined : 320\n});\n\n//Step 2: initialize a map - this map is centered over Europe\nvar map = new H.Map(document.getElementById(\'map\'),\n  defaultLayers.normal.map,{\n  center: {lat:41, lng:-87},\n  zoom: 4,\n  pixelRatio: pixelRatio\n});\n\n//Step 3: make the map interactive\n// MapEvents enables the event system\n// Behavior implements default interactions for pan/zoom (also on mobile touch environments)\nvar behavior = new H.mapevents.Behavior(new H.mapevents.MapEvents(map));\n\n// Create the default UI components\nvar ui = H.ui.UI.createDefault(map, defaultLayers);\n\n'

# %%
last_part
# Out:
# '\n\n// Now use the map as required...\naddMarkersToMap(map);\n  </script>\n</body>\n</html>\n'

# %%
def construct_middle_part(points):
    """
    input
    
    points: [(lat,lng), (lat,lng), ...]
    
    output
    
    string of
        var parisMarker = new H.map.Marker({lat:48.8567, lng:2.3508});
        map.addObject(parisMarker);
  
    """

    output_str = "var IconClst0 = new H.map.Icon(\"https://image.flaticon.com/icons/svg/252/252025.svg\", {size: {w: 32, h: 32}});"
    output_str += "var IconClst1 = new H.map.Icon(\"https://image.flaticon.com/icons/svg/58/58960.svg\", {size: {w: 32, h: 32}});"
    output_str += "var IconClst2 = new H.map.Icon(\"https://image.flaticon.com/icons/svg/149/149060.svg\", {size: {w: 32, h: 32}});"
    output_str += "var IconClst3 = new H.map.Icon(\"https://image.flaticon.com/icons/svg/1502/1502944.svg\", {size: {w: 32, h: 32}});"
    
    associated = kmeans(points, 4, max_iter=500, min_shift_frac=0.01)
    
    i = 0
    
    for p in points:
        output_str += """
            var parisMarker = new H.map.Marker({lat:%f, lng:%f}, {icon: IconClst%i});
            map.addObject(parisMarker);
        """ % (p[0], p[1], associated[i])
        i += 1
    return output_str

# %%
import csv

points = []
for iline, line in enumerate(open('crash2.csv', 'r')):
    if iline == 0: continue
    p = line.strip().split(",")
    points.append((float(p[0]),float(p[1])))

print(points)
# Out:
# [(41.89467657, -87.65732504), (41.89467657, -87.65732504), (41.89467657, -87.65732504), (41.89613412, -87.6565956), (41.89238383, -87.65772697), (41.89165427, -87.65725278), (41.89294663, -87.65757787), (41.89542528, -87.6551759), (41.89129371, -87.64768059), (41.89121804, -87.65468948), (41.89599599, -87.6524789), (41.89324215, -87.65570519), (41.89539756, -87.65576524), (41.89460555, -87.65732313), (41.8929702, -87.65598773), (41.8911581, -87.65911749), (41.89124229, -87.65235587), (41.89584197, -87.65481897), (41.89283282, -87.65768284), (41.89587084, -87.65607103), (41.89546625, -87.65576637), (41.89120814, -87.65573434), (41.89460555, -87.65732313), (41.89442373, -87.65761242), (41.89313364, -87.64780859), (41.8955426, -87.65542425), (41.89133821, -87.64894251), (41.89450195, -87.65339161), (41.89122956, -87.6535221), (41.89613873, -87.65634571), (41.89428162, -87.65350006), (41.89129371, -87.64768059), (41.89395876, -87.64784119), (41.89278268, -87.64776455), (41.89591575, -87.65468981), (41.89173287, -87.64865419), (41.89256389, -87.65792004), (41.8947061, -87.65280496), (41.89614582, -87.65601177), (41.89128065, -87.64855865), (41.89442373, -87.65761242), (41.89127925, -87.64885094), (41.89428162, -87.65350006), (41.89576285, -87.65130619), (41.89390208, -87.65646329), (41.89613873, -87.65634571), (41.89445591, -87.65407954), (41.89118941, -87.65747031), (41.89442788, -87.65340541), (41.89120814, -87.65573434), (41.89121804, -87.65468948), (41.89579624, -87.6549536), (41.89190342, -87.64864017), (41.89125752, -87.64793065), (41.89568793, -87.65433453), (41.89339094, -87.65705735), (41.89579624, -87.6549536), (41.89118941, -87.65747031), (41.89401286, -87.65232466), (41.89436046, -87.65761083), (41.89401888, -87.65126806), (41.89558431, -87.65538895), (41.89333047, -87.65691273), (41.89596155, -87.65506539), (41.8934848, -87.64773384), (41.89208581, -87.64917922), (41.89357111, -87.64782354), (41.89399896, -87.65638291), (41.89390062, -87.65680344), (41.89591575, -87.65468981), (41.89120657, -87.65587219), (41.89188849, -87.64776463), (41.89296105, -87.65756973), (41.8958262, -87.65276804), (41.89520367, -87.65275055), (41.89200173, -87.65726052), (41.8960858, -87.65944432), (41.8934542, -87.65012609), (41.89118941, -87.65747031), (41.89118941, -87.65747031), (41.8912745, -87.64933185), (41.89477227, -87.65607614), (41.89541722, -87.64950636), (41.89184551, -87.64881784), (41.89127925, -87.64885094), (41.89579624, -87.6549536), (41.89117069, -87.65905274), (41.89266134, -87.65727736), (41.8913637, -87.64776847), (41.89296105, -87.65756973), (41.89521608, -87.65570058), (41.8914627, -87.65885479), (41.89128618, -87.64803016), (41.8918756, -87.64842603), (41.89118845, -87.6575687), (41.89127957, -87.64873362), (41.89288438, -87.65728256), (41.8945699, -87.65732222), (41.89402448, -87.65176451), (41.89121902, -87.65906495), (41.89517817, -87.64786005), (41.89337977, -87.65793863), (41.89359184, -87.65153448), (41.89390208, -87.65646329), (41.89436458, -87.65731706), (41.8919185, -87.64849222), (41.8911581, -87.65911749), (41.8913637, -87.64776847), (41.89128065, -87.64855865), (41.89224629, -87.64943078), (41.89179257, -87.65824223), (41.89127957, -87.64873362), (41.89320701, -87.65701225), (41.89184551, -87.64881784), (41.89176978, -87.65860461), (41.89120272, -87.65621022), (41.89194878, -87.64892764), (41.89477317, -87.65762086), (41.89122719, -87.65378479), (41.89184551, -87.64881784), (41.89118845, -87.6575687), (41.89190342, -87.64864017), (41.89194878, -87.64892764), (41.8955426, -87.65542425), (41.8911635, -87.65954802), (41.89154382, -87.65594818), (41.89609485, -87.65887134), (41.89116306, -87.65963127), (41.89433299, -87.65610025), (41.89558108, -87.64786339), (41.89118941, -87.65747031), (41.89546625, -87.65576637), (41.89167749, -87.6477816), (41.89256389, -87.65792004), (41.89126587, -87.65000792), (41.89503317, -87.65342332), (41.89614823, -87.65590893), (41.89211996, -87.64909797), (41.89121804, -87.6546894 ...

# %%
middle = construct_middle_part(points)
middle
# Out:
# changed_fraction(0.0) reached to min_shift_frac(0.01)
# 'var IconClst0 = new H.map.Icon("https://image.flaticon.com/icons/svg/252/252025.svg", {size: {w: 32, h: 32}});var IconClst1 = new H.map.Icon("https://image.flaticon.com/icons/svg/58/58960.svg", {size: {w: 32, h: 32}});var IconClst2 = new H.map.Icon("https://image.flaticon.com/icons/svg/149/149060.svg", {size: {w: 32, h: 32}});var IconClst3 = new H.map.Icon("https://image.flaticon.com/icons/svg/1502/1502944.svg", {size: {w: 32, h: 32}});\n            var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.896134, lng:-87.656596}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.892384, lng:-87.657727}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891654, lng:-87.657253}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.892947, lng:-87.657578}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895425, lng:-87.655176}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891294, lng:-87.647681}, {icon: IconClst2});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891218, lng:-87.654689}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895996, lng:-87.652479}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.893242, lng:-87.655705}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895398, lng:-87.655765}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894606, lng:-87.657323}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.892970, lng:-87.655988}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891158, lng:-87.659117}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891242, lng:-87.652356}, {icon: IconClst2});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895842, lng:-87.654819}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.892833, lng:-87.657683}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895871, lng:-87.656071}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895466, lng:-87.655766}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891208, lng:-87.655734}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894606, lng:-87.657323}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894424 ...

# %%
whole = first_part + middle + last_part
whole
# Out:
# '\n<!DOCTYPE html>\n<html>\n<head>\n<meta name="viewport" content="initial-scale=1.0, width=device-width" />\n<link rel="stylesheet" type="text/css" href="https://js.api.here.com/v3/3.0/mapsjs-ui.css?dp-version=1542186754" />\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-core.js"></script>\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-service.js"></script>\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-ui.js"></script>\n<script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-mapevents.js"></script>\n\n</head>\n<body>\n  <div id="map" style="width: 100%; height: 800px; background: grey" />\n  <script  type="text/javascript" charset="UTF-8" >\n    \n\n/**\n * Adds markers to the map highlighting the locations of the captials of\n * France, Italy, Germany, Spain and the United Kingdom.\n *\n * @param  {H.Map} map      A HERE Map instance within the application\n */\nfunction addMarkersToMap(map) {\n  //var parisMarker = new H.map.Marker({lat:48.8567, lng:2.3508});\n  //map.addObject(parisMarker);\n}\n\n/**\n * Boilerplate map initialization code starts below:\n */\n\n//Step 1: initialize communication with the platform\nvar platform = new H.service.Platform({\n  app_id: \'devportal-demo-20180625\',\n  app_code: \'9v2BkviRwi9Ot26kp2IysQ\',\n  useHTTPS: true\n});\nvar pixelRatio = window.devicePixelRatio || 1;\nvar defaultLayers = platform.createDefaultLayers({\n  tileSize: pixelRatio === 1 ? 256 : 512,\n  ppi: pixelRatio === 1 ? undefined : 320\n});\n\n//Step 2: initialize a map - this map is centered over Europe\nvar map = new H.Map(document.getElementById(\'map\'),\n  defaultLayers.normal.map,{\n  center: {lat:41, lng:-87},\n  zoom: 4,\n  pixelRatio: pixelRatio\n});\n\n//Step 3: make the map interactive\n// MapEvents enables the event system\n// Behavior implements default interactions for pan/zoom (also on mobile touch environments)\nvar behavior = new H.mapevents.Behavior(new H.mapevents.MapEvents(map));\n\n// Create the default UI components\nvar ui = H.ui.UI.createDefault(map, defaultLayers);\n\nvar IconClst0 = new H.map.Icon("https://image.flaticon.com/icons/svg/252/252025.svg", {size: {w: 32, h: 32}});var IconClst1 = new H.map.Icon("https://image.flaticon.com/icons/svg/58/58960.svg", {size: {w: 32, h: 32}});var IconClst2 = new H.map.Icon("https://image.flaticon.com/icons/svg/149/149060.svg", {size: {w: 32, h: 32}});var IconClst3 = new H.map.Icon("https://image.flaticon.com/icons/svg/1502/1502944.svg", {size: {w: 32, h: 32}});\n            var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.896134, lng:-87.656596}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.892384, lng:-87.657727}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891654, lng:-87.657253}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.892947, lng:-87.657578}, {icon: IconClst0});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.895425, lng:-87.655176}, {icon: IconClst3});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:41.891294, lng:-87.647681}, {icon: IconClst2});\n            map.addObject(parisMarker);\n        \n            var parisMarker = new H.map.Marker({lat:4 ...

# %%
from IPython.display import HTML
display(HTML(whole))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta name="viewport" content="initial-scale=1.0, width=device-width" />
# <link rel="stylesheet" type="text/css" href="https://js.api.here.com/v3/3.0/mapsjs-ui.css?dp-version=1542186754" />
# <script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-core.js"></script>
# <script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-service.js"></script>
# <script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-ui.js"></script>
# <script type="text/javascript" src="https://js.api.here.com/v3/3.0/mapsjs-mapevents.js"></script>
#
# </head>
# <body>
#   <div id="map" style="width: 100%; height: 800px; background: grey" />
#   <script  type="text/javascript" charset="UTF-8" >
#
#
# /**
#  * Adds markers to the map highlighting the locations of the captials of
#  * France, Italy, Germany, Spain and the United Kingdom.
#  *
#  * @param  {H.Map} map      A HERE Map instance within the application
#  */
# function addMarkersToMap(map) {
#   //var parisMarker = new H.map.Marker({lat:48.8567, lng:2.3508});
#   //map.addObject(parisMarker);
# }
#
# /**
#  * Boilerplate map initialization code starts below:
#  */
#
# //Step 1: initialize communication with the platform
# var platform = new H.service.Platform({
#   app_id: 'devportal-demo-20180625',
#   app_code: '9v2BkviRwi9Ot26kp2IysQ',
#   useHTTPS: true
# });
# var pixelRatio = window.devicePixelRatio || 1;
# var defaultLayers = platform.createDefaultLayers({
#   tileSize: pixelRatio === 1 ? 256 : 512,
#   ppi: pixelRatio === 1 ? undefined : 320
# });
#
# //Step 2: initialize a map - this map is centered over Europe
# var map = new H.Map(document.getElementById('map'),
#   defaultLayers.normal.map,{
#   center: {lat:41, lng:-87},
#   zoom: 4,
#   pixelRatio: pixelRatio
# });
#
# //Step 3: make the map interactive
# // MapEvents enables the event system
# // Behavior implements default interactions for pan/zoom (also on mobile touch environments)
# var behavior = new H.mapevents.Behavior(new H.mapevents.MapEvents(map));
#
# // Create the default UI components
# var ui = H.ui.UI.createDefault(map, defaultLayers);
#
# var IconClst0 = new H.map.Icon("https://image.flaticon.com/icons/svg/252/252025.svg", {size: {w: 32, h: 32}});var IconClst1 = new H.map.Icon("https://image.flaticon.com/icons/svg/58/58960.svg", {size: {w: 32, h: 32}});var IconClst2 = new H.map.Icon("https://image.flaticon.com/icons/svg/149/149060.svg", {size: {w: 32, h: 32}});var IconClst3 = new H.map.Icon("https://image.flaticon.com/icons/svg/1502/1502944.svg", {size: {w: 32, h: 32}});
#             var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894677, lng:-87.657325}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.896134, lng:-87.656596}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.892384, lng:-87.657727}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891654, lng:-87.657253}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.892947, lng:-87.657578}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895425, lng:-87.655176}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891294, lng:-87.647681}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891218, lng:-87.654689}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895996, lng:-87.652479}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.893242, lng:-87.655705}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895398, lng:-87.655765}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894606, lng:-87.657323}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.892970, lng:-87.655988}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891158, lng:-87.659117}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891242, lng:-87.652356}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895842, lng:-87.654819}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.892833, lng:-87.657683}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895871, lng:-87.656071}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895466, lng:-87.655766}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891208, lng:-87.655734}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894606, lng:-87.657323}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894424, lng:-87.657612}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.893134, lng:-87.647809}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895543, lng:-87.655424}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891338, lng:-87.648943}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894502, lng:-87.653392}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891230, lng:-87.653522}, {icon: IconClst0});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.896139, lng:-87.656346}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.894282, lng:-87.653500}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891294, lng:-87.647681}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.893959, lng:-87.647841}, {icon: IconClst1});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.892783, lng:-87.647765}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.895916, lng:-87.654690}, {icon: IconClst3});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.891733, lng:-87.648654}, {icon: IconClst2});
#             map.addObject(parisMarker);
#
#             var parisMarker = new H.map.Marker({lat:41.892564, lng:-87.657920}, {icon: IconClst0});
#             map.addObject

# %%
f = open("whole_map2.html", "w")

f.write(whole)

f.close()

# %%
import gmaps
